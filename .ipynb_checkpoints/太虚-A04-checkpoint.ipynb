# %%
import pandas as pd
import numpy as np
data1=pd.read_csv('A04_train.csv')
data1.tail()
# Out:
#              fz   temp_max   bc  bc_2   ms
# 4436  17.534247  500959278 -233   -23  137
# 4437  17.194444  500959278 -233   -23  138
# 4438  17.342466  500959278 -233   -23  139
# 4439  20.902778  500959278 -233   -23  140
# 4440  16.863014  500959278 -233   -23  141

# %%
data1.drop(['bc'],axis=1,inplace=True)
data1
# Out:
#              fz   temp_max  bc_2   ms
# 0     17.823529  501024808     0    0
# 1     19.554839  501024805     0    1
# 2     18.838150  501024807     0    2
# 3     18.456140  501024809     0    3
# 4     18.339181  501024809     0    4
# 5     18.197674  501024809     0    5
# 6     18.751445  501024809     0    6
# 7     19.286550  501024807     0    7
# 8     19.432749  501024808     0    8
# 9     18.695906  501024806    -5    9
# 10    18.491228  501024807    -5   10
# 11    18.567251  501024805    -5   11
# 12    18.789474  501024809    -5   12
# 13    20.144509  501024806    -5   13
# 14    18.923977  501024809    -5   14
# 15    18.111111  501024807    -5   15
# 16    18.691860  501024809    -5   16
# 17    18.488372  501024809    -5   17
# 18    19.163743  501024809    -5   18
# 19    18.245614  501024807    -5   19
# 20    18.216374  501024809    -5   20
# 21    18.824561  501024806    -5   21
# 22    19.853801  501024809    -5   22
# 23    18.625731  501024808    -5   23
# 24    18.505814  501024807    -5   24
# 25    18.406977  501024806    -5   25
# 26    19.127907  501024806    -5   26
# 27    19.197674  501024810    -5   27
# 28    18.581395  501024809    -5   28
# 29    18.280702  501024806    -5   29
# ...         ...        ...   ...  ...
# 4411  17.095890  500959278   -23  112
# 4412  16.958333  500959279   -23  113
# 4413  17.246575  500959277   -23  114
# 4414  25.305556  500959275   -23  115
# 4415  18.864865  500959279   -23  116
# 4416  17.083333  500959277   -23  117
# 4417  18.589041  500959275   -23  118
# 4418  17.000000  500959278   -23  119
# 4419  16.861111  500959277   -23  120
# 4420  17.219178  500959279   -23  121
# 4421  17.055556  500959279   -23  122
# 4422  17.109589  500959279   -23  123
# 4423  17.150685  500959278   -23  124
# 4424  16.958904  500959279   -23  125
# 4425  16.876712  500959277   -23  126
# 4426  17.219178  500959274   -23  127
# 4427  17.397260  500959276   -23  128
# 4428  16.904110  500959274   -23  129
# 4429  17.068493  500959273   -23  130
# 4430  17.041096  500959276   -23  131
# 4431  17.452055  500959277   -23  132
# 4432  16.797297  500959278   -23  133
# 4433  17.219178  500959274   -23  134
# 4434  16.729730  500959274   -23  135
# 4435  16.888889  500959276   -23  136
# 4436  17.534247  500959278   -23  137
# 4437  17.194444  500959278   -23  138
# 4438  17.342466  500959278   -23  139
# 4439  20.902778  500959278   -23  140
# 4440  16.863014  500959278   -23  141
#
# [4441 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
np.random.seed(21)
target = data1['fz']
data1.drop('fz', axis=1, inplace=True)
train_data, val_data, train_y, val_y = train_test_split(
    data1, target, train_size=0.8, random_state=21
)
# Out:
# D:\anaconda\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

def simple_linear_model(train_data, train_y, val_data, val_y, input_feature):
    reg = LinearRegression()
    reg.fit(train_data.as_matrix(columns=[input_feature]), train_y)
    RMSE = mean_squared_error(
        val_y, reg.predict(val_data.as_matrix(columns=[input_feature]))
    ) ** 0.5
    return RMSE

# %%
estimate_result = pd.DataFrame(columns=['feature', 'Val_RMSE'])

np.random.seed(21)

for feature in train_data.columns:
    RMSE = simple_linear_model(train_data, train_y, val_data, val_y, feature)
    estimate_result = estimate_result.append({'feature': feature, 'Val_RMSE': RMSE}, ignore_index=True)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
estimate_result.sort_values(by='Val_RMSE').head(3)
# Out:
#     feature  Val_RMSE
# 0  temp_max  1.337954
# 1      bc_2  1.451234
# 2        ms  1.451507

# %%
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

np.random.seed(21)

def regression_model(reg, train_data, train_y, val_data, val_y, input_feature):
    reg.fit(train_data.as_matrix(columns=input_feature), train_y)
    RMSE = mean_squared_error(
        val_y, reg.predict(val_data.as_matrix(columns=input_feature))
    ) ** 0.5
    return reg, RMSE

ridge = Ridge()
dt_gre = DecisionTreeRegressor()
rf_reg = RandomForestRegressor()
ridge, RMSE = regression_model(ridge, train_data, train_y, val_data, val_y, train_data.columns)
print('RMSE for ridge_regression is %s' % RMSE)
dt_gre, RMSE = regression_model(dt_gre, train_data, train_y, val_data, val_y, train_data.columns)
print('RMSE for DecisionTreeRegressor is %s' % RMSE)
rf_reg, RMSE = regression_model(rf_reg, train_data, train_y, val_data, val_y, train_data.columns)
print('RMSE for RandomForestRegressor is %s' % RMSE)
# Out:
# RMSE for ridge_regression is 1.338810864606966
# RMSE for DecisionTreeRegressor is 1.8153472431041826
# RMSE for RandomForestRegressor is 1.5759097675558955
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\anaconda\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
test=pd.read_csv('A04_test.csv')
test.drop(['bc'],axis=1,inplace=True)
test_y=test['fz']
test_data=test.drop(['fz'],axis=1,inplace=True)
test
# Out:
#       temp_max  bc_2   ms
# 0    500959278   -23  142
# 1    500959278   -23  143
# 2    500959276   -23  144
# 3    500959277   -23  145
# 4    500959278   -23  146
# 5    500959274   -23  147
# 6    500959274   -23  148
# 7    500959274   -23  149
# 8    500959278   -23  150
# 9    500959278   -23  151
# 10   500959276   -23  152
# 11   500959279   -23  153
# 12   500959275   -23  154
# 13   500959275   -23  155
# 14   500959278   -23  156
# 15   500959279   -23  157
# 16   500959279   -23  158
# 17   500959279   -23  159
# 18   500959276   -23  160
# 19   500959280   -23  161
# 20   500959279   -23  162
# 21   500959280   -23  163
# 22   500959279   -23  164
# 23   500959279   -23  165
# 24   500959278   -23  166
# 25   500959279   -23  167
# 26   500959281   -23  168
# 27   500959280   -23  169
# 28   500959281   -23  170
# 29   500959280   -23  171
# ..         ...   ...  ...
# 970  500959280   -40  221
# 971  500959279   -40  222
# 972  500959278     0    0
# 973  500959277     0    1
# 974  500959279     0    2
# 975  500959279     0    3
# 976  500959279     0    4
# 977  500959276     0    5
# 978  500959280     0    6
# 979  500959276     0    7
# 980  500959277     0    8
# 981  500959275     0    9
# 982  500959279     0   10
# 983  500959276     0   11
# 984  500959280     0   12
# 985  500959276     0   13
# 986  500959279     0   14
# 987  500959279     0   15
# 988  500959276     0   16
# 989  500959277     0   17
# 990  500959280     0   18
# 991  500959280     0   19
# 992  500959279     0   20
# 993  500959279    10   21
# 994  500959279    10   22
# 995  500959280    10   23
# 996  500959278     0   24
# 997  500959280     0   25
# 998  500959280    -8   26
# 999  500959280    -8   27
#
# [1000 rows x 3 columns]

# %%
plt.figure(figsize=(20,12))
plt.plot(test_y,c='red')
plt.plot(dt_gre.predict(test),c='blue')
plt.show()

# %%
plt.figure(figsize=(20,12))
plt.plot(test_y,c='red')
plt.plot(rf_reg.predict(test),c='blue')
plt.show()

# %%
plt.figure(figsize=(20,12))
plt.plot(test_y,c='red')
plt.plot(ridge.predict(test),c='blue')
plt.show()

# %%
rf_reg.score(test,test_y)
# Out:
# -0.43945318940434186

# %%
dt_gre.score(test,test_y)
# Out:
# -1.2548843648642558

# %%
ridge.score(test,test_y)
# Out:
# -0.047140832800923294
