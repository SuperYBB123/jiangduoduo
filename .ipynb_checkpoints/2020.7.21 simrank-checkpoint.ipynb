# %%
import pandas as pd
import numpy as np
import random
import csv

# %%
user_interest=pd.read_csv(r'F:\work\7.21 simrank++\平滑k=5.csv')
interest_dict=dict()
#group_dict=dict()
for i in user_interest.index:
    device=user_interest['deviceid'][i]
#    active_days=user_interest['active_days'][i]
#    group_dict.setdefault(active_days,[])
#    group_dict[active_days].append(device)
    interest_dict.setdefault(device,{})
    for s in range(1,26):
        name='theme_'+str(s)
        j=user_interest[name][i]
        interest_dict[device][str(s)]=j
#interest_dict

# %%
#数据转为字典
group_dict=dict()
with open(r'F:\work\7.21 simrank++\活跃天数14天.csv',encoding='utf_8_sig') as f:
    f.readline()
    for line in f:
        deviceid,active_days=line.strip().split(',')
        group_dict.setdefault(active_days,[])
        group_dict[active_days].append(deviceid)
group_dict

# %%
user_interest_0=pd.read_csv(r'F:\work\7.21 simrank++\兴趣平滑7.csv')
interest_dict_0=dict()
#group_dict=dict()
for i in user_interest_0.index:
    device=user_interest_0['deviceid'][i]
#    active_days=user_interest['active_days'][i]
#    group_dict.setdefault(active_days,[])
#    group_dict[active_days].append(device)
    interest_dict_0.setdefault(device,{})
    for s in range(1,26):
        name='theme_'+str(s)
        j=user_interest_0[name][i]
        interest_dict_0[device][str(s)]=j
#interest_dict

# %%
user_interest_1=pd.read_csv(r'F:\work\7.21 simrank++\兴趣平滑3.csv')
interest_dict_1=dict()
#group_dict=dict()
for i in user_interest_1.index:
    device=user_interest_1['deviceid'][i]
#    active_days=user_interest['active_days'][i]
#    group_dict.setdefault(active_days,[])
#    group_dict[active_days].append(device)
    interest_dict_1.setdefault(device,{})
    for s in range(1,26):
        name='theme_'+str(s)
        j=user_interest_1[name][i]
        interest_dict_1[device][str(s)]=j
#interest_dict

# %%
user_interest_2=pd.read_csv(r'F:\work\7.21 simrank++\兴趣平滑1.csv')
interest_dict_2=dict()
#group_dict=dict()
for i in user_interest_2.index:
    device=user_interest_2['deviceid'][i]
#    active_days=user_interest['active_days'][i]
#    group_dict.setdefault(active_days,[])
#    group_dict[active_days].append(device)
    interest_dict_2.setdefault(device,{})
    for s in range(1,26):
        name='theme_'+str(s)
        j=user_interest_2[name][i]
        interest_dict_2[device][str(s)]=j
#interest_dict

# %%
#数据转为字典
theme_dict=dict()
essay_theme_dict=dict()
ctr_dict=dict()
with open(r'F:\work\7.21 simrank++\theme_ctr_500_3.csv',encoding='utf_8_sig') as f:
    f.readline()
    for line in f:
        itemid,theme,clicks,exposes,ctr,ctr2=line.strip().split(',')
        essay_theme_dict[itemid]=theme
        theme_dict.setdefault(theme,[])
        theme_dict[theme].append(itemid)
        ctr_dict[itemid]=float(ctr2)
#theme_dict

# %%
#avg=np.mean(list(ctr_dict.values()))
avg=0.065
rec_essay_theme=dict()
for i in ctr_dict.keys():
    if ctr_dict[i]>avg:
        e_theme=essay_theme_dict[i]
        rec_essay_theme.setdefault(e_theme,{})
        rec_essay_theme[e_theme][i]=ctr_dict[i]
for i in range(1,26):
    print(i,len(rec_essay_theme[str(i)]))
# Out:
# 1 95
# 2 81
# 3 87
# 4 100
# 5 95
# 6 97
# 7 109
# 8 108
# 9 84
# 10 92
# 11 94
# 12 85
# 13 98
# 14 84
# 15 86
# 16 81
# 17 78
# 18 74
# 19 81
# 20 94
# 21 88
# 22 83
# 23 97
# 24 87
# 25 94

# %%
tmp=pd.read_csv(r'F:\work\7.21 simrank++\test_expose_1.csv',encoding='utf-8')
test_expose_dict={}
for i in tmp.index:
    device=tmp['deviceid'][i]
    j=tmp['list'][i]
    k=j.strip().split(',')
    test_expose_dict[device]=k
tmp=pd.read_csv(r'F:\work\7.21 simrank++\test_click_1.csv',encoding='utf-8')
test_click_dict={}
for i in tmp.index:
    device=tmp['deviceid'][i]
    j=tmp['list'][i]
    k=j.strip().split(',')
    test_click_dict[device]=k

# %%
device_list=[]
for user in interest_dict.keys():
    if user in test_expose_dict.keys():
        if user in test_click_dict.keys():
            device_list.append(user)
sample_users=random.sample(device_list,10000)
len(device_list)
# Out:
# 180218

# %%
#14
for a in [x/10 for x in range(1,4)]:
    ACC=[]
    RECALL=[]
    expose_ACC=[]
    for user in sample_users:
        score_dict=dict()
        max_label=max(list(interest_dict[user].values()))
        for label in interest_dict[user].keys():
            label_score=interest_dict[user][label]/max_label         #兴趣分
            tmp_dict={v:a*label_score+(1-a)*k for v,k in rec_essay_theme[label].items()}           #兴趣分*ctr
            score_dict.update(tmp_dict)
        rec_sorted=sorted(score_dict.items(),key=lambda x:x[1],reverse=True)
        rec_list=[x[0] for x in rec_sorted]
        rec=sorted(set(rec_list),key=rec_list.index)[:100]
        exposed=[x for x in rec if x in test_expose_dict[user]]
        if len(exposed)>0:
            true=[x for x in rec if x in test_click_dict[user]]
            po=[x for x in test_click_dict[user] if x in rec]
            acc=len(true)/len(rec)
            recall=len(po)/len(test_click_dict[user])
            ACC.append(acc)
            RECALL.append(recall)
            expose_acc=len(true)/len(exposed)
            expose_ACC.append(expose_acc)
#            if sample_users.index(user)%1000==0:
#                print(sample_users.index(user))
    print(a,np.mean(ACC),np.mean(RECALL),np.mean(expose_ACC),2*np.mean(RECALL)*np.mean(expose_ACC)/(np.mean(RECALL)+np.mean(expose_ACC)),len(ACC))
# Out:
# 0.0 0.009457857452652884 0.22449020714520682 0.2922542254936606 0.25392905071116606 6917
# 0.1 0.009374641422834194 0.22330002571594013 0.2933021779420914 0.253558283000917 6972
# 0.2 0.009159723202937438 0.217286391864816 0.28765966414594646 0.24756914035975855 7081
# 0.3 0.008614399108759226 0.2005575575216697 0.2711934378189285 0.2305872972905984 7181

# %%
#7
for a in [x/10 for x in range(1,2)]:
    ACC=[]
    RECALL=[]
    expose_ACC=[]
    for user in sample_users:
        score_dict=dict()
        max_label=max(list(interest_dict_0[user].values()))
        for label in interest_dict_0[user].keys():
            label_score=interest_dict_0[user][label]/max_label         #兴趣分
            tmp_dict={v:a*label_score+(1-a)*k for v,k in rec_essay_theme[label].items()}           #兴趣分*ctr
            score_dict.update(tmp_dict)
        rec_sorted=sorted(score_dict.items(),key=lambda x:x[1],reverse=True)
        rec_list=[x[0] for x in rec_sorted]
        rec=sorted(set(rec_list),key=rec_list.index)[:100]
        exposed=[x for x in rec if x in test_expose_dict[user]]
        if len(exposed)>0:
            true=[x for x in rec if x in test_click_dict[user]]
            po=[x for x in test_click_dict[user] if x in rec]
            acc=len(true)/len(rec)
            recall=len(po)/len(test_click_dict[user])
            ACC.append(acc)
            RECALL.append(recall)
            expose_acc=len(true)/len(exposed)
            expose_ACC.append(expose_acc)
#            if sample_users.index(user)%1000==0:
#                print(sample_users.index(user))
    print(a,np.mean(ACC),np.mean(RECALL),np.mean(expose_ACC),2*np.mean(RECALL)*np.mean(expose_ACC)/(np.mean(RECALL)+np.mean(expose_ACC)),len(ACC))

# %%
#3
for a in [x/10 for x in range(1,2)]:
    ACC=[]
    RECALL=[]
    expose_ACC=[]
    for user in sample_users:
        score_dict=dict()
        max_label=max(list(interest_dict_1[user].values()))
        for label in interest_dict_1[user].keys():
            label_score=interest_dict_1[user][label]/max_label         #兴趣分
            tmp_dict={v:a*label_score+(1-a)*k for v,k in rec_essay_theme[label].items()}           #兴趣分*ctr
            score_dict.update(tmp_dict)
        rec_sorted=sorted(score_dict.items(),key=lambda x:x[1],reverse=True)
        rec_list=[x[0] for x in rec_sorted]
        rec=sorted(set(rec_list),key=rec_list.index)[:100]
        exposed=[x for x in rec if x in test_expose_dict[user]]
        if len(exposed)>0:
            true=[x for x in rec if x in test_click_dict[user]]
            po=[x for x in test_click_dict[user] if x in rec]
            acc=len(true)/len(rec)
            recall=len(po)/len(test_click_dict[user])
            ACC.append(acc)
            RECALL.append(recall)
            expose_acc=len(true)/len(exposed)
            expose_ACC.append(expose_acc)
#        if sample_users.index(user)%1000==0:
#            print(sample_users.index(user))
    print(a,np.mean(ACC),np.mean(RECALL),np.mean(expose_ACC),2*np.mean(RECALL)*np.mean(expose_ACC)/(np.mean(RECALL)+np.mean(expose_ACC)),len(ACC))

# %%
#1
for a in [x/10 for x in range(1,2)]:
    ACC=[]
    RECALL=[]
    expose_ACC=[]
    for user in sample_users:
        score_dict=dict()
        max_label=max(list(interest_dict_2[user].values()))
        for label in interest_dict_2[user].keys():
            label_score=interest_dict_2[user][label]/max_label         #兴趣分
            tmp_dict={v:a*label_score+(1-a)*k for v,k in rec_essay_theme[label].items()}           #兴趣分*ctr
            score_dict.update(tmp_dict)
        rec_sorted=sorted(score_dict.items(),key=lambda x:x[1],reverse=True)
        rec_list=[x[0] for x in rec_sorted]
        rec=sorted(set(rec_list),key=rec_list.index)[:100]
        exposed=[x for x in rec if x in test_expose_dict[user]]
        if len(exposed)>0:
            true=[x for x in rec if x in test_click_dict[user]]
            po=[x for x in test_click_dict[user] if x in rec]
            acc=len(true)/len(rec)
            recall=len(po)/len(test_click_dict[user])
            ACC.append(acc)
            RECALL.append(recall)
            expose_acc=len(true)/len(exposed)
            expose_ACC.append(expose_acc)
#        if sample_users.index(user)%1000==0:
#            print(sample_users.index(user))
    print(a,np.mean(ACC),np.mean(RECALL),np.mean(expose_ACC),2*np.mean(RECALL)*np.mean(expose_ACC)/(np.mean(RECALL)+np.mean(expose_ACC)),len(ACC))

# %%
rec_sorted=sorted(ctr_dict.items(),key=lambda x:x[1],reverse=True)
rec_list=[x[0] for x in rec_sorted]
rec=sorted(set(rec_list),key=rec_list.index)[:100]
ACC=[]
RECALL=[]
expose_ACC=[]
for user in device_list:
    exposed=[x for x in rec if x in test_expose_dict[user]]
    if len(exposed)>0:
        true=[x for x in rec if x in test_click_dict[user]]
        po=[x for x in test_click_dict[user] if x in rec]
        acc=len(true)/len(rec)
        recall=len(po)/len(test_click_dict[user])
        ACC.append(acc)
        RECALL.append(recall)
        expose_acc=len(true)/len(exposed)
        expose_ACC.append(expose_acc)
#    if device_list.index(user)%5000==0:
#        print(device_list.index(user))
print(np.mean(ACC),np.mean(RECALL),np.mean(expose_ACC),2*np.mean(RECALL)*np.mean(expose_ACC)/(np.mean(RECALL)+np.mean(expose_ACC)),len(ACC))
# Out:
# 0.009675780535119504 0.22766587458737997 0.29518160315979824 0.2570645578517112 136605

# %%
'''
interest_avg=0.069276824
select_interest_dict=dict()
for i in user_interest.index:
    device=user_interest['deviceid'][i]
    for s in range(1,26):
        name='theme_'+str(s)
        j=user_interest[name][i]
        if j>=interest_avg:
            select_interest_dict.setdefault(device,{})
            select_interest_dict[device][str(s)]=j
'''
# Out:
# [('2505615', 0.8198742097),
#  ('2480470', 0.7938042656000001),
#  ('2505772', 0.5881557461),
#  ('2515060', 0.5699545039),
#  ('2388562', 0.564067486),
#  ('2227610', 0.5183602435),
#  ('2585596', 0.5154048685),
#  ('2001602', 0.5099667521000001),
#  ('2514685', 0.5061669607),
#  ('2255899', 0.4937465602000001),
#  ('2525113', 0.48656601769999996),
#  ('2240266', 0.4861498487),
#  ('2573715', 0.4826222285),
#  ('2444630', 0.4767645655),
#  ('2550322', 0.4756147844),
#  ('2499493', 0.47239809490000007),
#  ('2196745', 0.4715139412),
#  ('2434088', 0.466891232),
#  ('2515915', 0.4658712575),
#  ('2433490', 0.45802127440000007),
#  ('2285262', 0.4474163741),
#  ('1838577', 0.4434651797),
#  ('2403185', 0.439315664),
#  ('2174594', 0.4373624399),
#  ('2550474', 0.4337761892),
#  ('2227785', 0.42284417500000004),
#  ('2327592', 0.4218224734),
#  ('2447279', 0.4216304341),
#  ('2327653', 0.42118509740000004),
#  ('2474886', 0.4164797197000001),
#  ('2136654', 0.41446377949999996),
#  ('2458587', 0.4139348419000001),
#  ('2403236', 0.4123464602),
#  ('2474873', 0.40954621420000004),
#  ('1853173', 0.4078288697),
#  ('2189677', 0.39979719189999996),
#  ('2227780', 0.3979496327),
#  ('2237593', 0.39794122089999995),
#  ('2196752', 0.393522863),
#  ('2433744', 0.3889580158),
#  ('2316321', 0.3875919067),
#  ('2222647', 0.38039437579999996),
#  ('2403162', 0.3737654303),
#  ('2065386', 0.37364977629999996),
#  ('2573205', 0.37292699300000004),
#  ('2581350', 0.3714774085),
#  ('2403207', 0.3697707713),
#  ('2604116', 0.3678638302),
#  ('1926517', 0.36433886410000005),
#  ('2190999', 0.3632268497),
#  ('2450999', 0.35945305660000004),
#  ('2404482', 0.3592305311),
#  ('2073377', 0.3587227246),
#  ('2577034', 0.3581299693000001),
#  ('2420247', 0.3578889016),
#  ('2500242', 0.35771032540000003),
#  ('2531160', 0.3569840834),
