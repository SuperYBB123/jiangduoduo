
import matplotlib.pyplot as plt
plt.figure(figsize=(20,12))
plt.plot(binancey,c='red')
plt.show()

# %%
binance_train=binancey.head(1500)
binance_test=binancey.tail(100)

# %%
binance_test
# Out:
# 53378    9480.96
# 53423    9479.03
# 53463    9478.95
# 53507    9477.28
# 53554    9473.71
# 53600    9472.23
# 53646    9467.06
# 53684    9469.72
# 53730    9466.16
# 53776    9464.63
# 53814    9470.21
# 53860    9458.69
# 53862    9463.99
# 53909    9458.82
# 53948    9452.85
# 53995    9451.13
# 54042    9451.87
# 54089    9450.00
# 54125    9446.27
# 54170    9436.07
# 54213    9451.85
# 54233    9464.99
# 54277    9465.00
# 54321    9449.20
# 54366    9444.00
# 54406    9442.53
# 54450    9443.86
# 54497    9444.24
# 54543    9432.75
# 54589    9417.00
#           ...
# 56252    9488.44
# 56292    9504.86
# 56336    9498.85
# 56383    9498.16
# 56429    9486.88
# 56475    9478.37
# 56513    9479.19
# 56559    9477.80
# 56605    9472.12
# 56643    9465.74
# 56689    9461.15
# 56691    9466.31
# 56738    9466.13
# 56777    9467.30
# 56824    9467.34
# 56871    9461.95
# 56918    9462.15
# 56954    9464.82
# 56999    9459.48
# 57042    9464.04
# 57062    9465.00
# ...

# %%
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %%
LR=LinearRegression()
DT=DecisionTreeRegressor()
RF=RandomForestRegressor()

# %% [markdown]
# a=np.array(range(1500))
# index=a.reshape(-1, 1)
# index,binance_train

# %%
a=np.array(range(1500)) 
index=a.reshape(-1, 1) 
index.shape,binance_train.shape
# Out:
# ((1500, 1), (1500,))

# %%
RF.fit(X=index,y=binance_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
b=np.array(range(100)) 
index1=b.reshape(-1, 1) 
result=RF.predict(index1)
result
# Out:
# array([9497.612, 9495.131, 9493.086, 9490.632, 9491.001, 9487.793,
#        9487.016, 9487.276, 9487.1  , 9484.92 , 9484.01 , 9483.312,
#        9483.153, 9481.805, 9479.957, 9478.497, 9476.987, 9476.187,
#        9474.734, 9473.752, 9469.97 , 9462.944, 9459.978, 9459.188,
#        9458.59 , 9457.934, 9456.438, 9458.688, 9458.832, 9452.194,
#        9441.41 , 9442.43 , 9443.87 , 9440.334, 9437.336, 9436.421,
#        9439.474, 9458.834, 9480.468, 9494.334, 9495.923, 9492.95 ,
#        9492.205, 9491.96 , 9496.329, 9496.245, 9490.19 , 9488.5  ,
#        9488.5  , 9488.108, 9485.756, 9491.538, 9493.358, 9493.097,
#        9490.315, 9487.511, 9490.813, 9493.017, 9494.069, 9491.452,
#        9487.254, 9477.897, 9465.139, 9465.419, 9457.476, 9452.663,
#        9456.147, 9454.872, 9448.962, 9448.192, 9448.288, 9446.364,
#        9444.859, 9445.06 , 9444.64 , 9450.31 , 9462.694, 9462.65 ,
#        9456.898, 9451.12 , 9446.44 , 9441.049, 9429.11 , 9419.692,
# ...

# %% [markdown]
# test=[]
# for i in binance_test:
#     test.append(i)
# np.array(test).reshape(-1,1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,12))
plt.plot(result,c='red')
plt.plot(test,c='blue')
plt.show()
