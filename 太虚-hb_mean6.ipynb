# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False
hb_mean6=pd.read_csv('hb_mean6_1.csv',encoding="gbk")

# %%
hb_mean6.head(10)
# Out:
#                             Unnamed: 0  串联主轴齿轮比-S   串行主轴负载信息-S  主轴平均负载-S  \
# 0  2019-04-03 04:45:31.249498243+00:00     4768.0  1124.058824  1.352941
# 1  2019-04-03 04:49:29.663994018+00:00     4768.0   391.129032  2.593548
# 2  2019-04-03 04:59:44.046301394+00:00     4768.0   452.416185  2.867052
# 3  2019-04-03 05:06:50.351216254+00:00     4768.0   547.017544  2.561404
# 4  2019-04-03 05:13:56.531225401+00:00     4768.0   641.456140  2.105263
# 5  2019-04-03 05:21:06.531130301+00:00     4768.0   462.191861  1.604651
# 6  2019-04-03 05:28:10.239737986+00:00     4768.0   361.063584  3.260116
# 7  2019-04-03 05:35:16.474476054+00:00     4768.0   365.339181  2.298246
# 8  2019-04-03 05:42:22.849197752+00:00     4768.0   535.894737  2.233918
# 9  2019-04-03 05:49:29.276126319+00:00     4768.0   503.345029  2.497076
#
#       主轴电机温度-S    主轴负载-S   伺服电机温度-A  伺服电机温度-C  伺服电机温度-X   伺服电机温度-Y ...  \
# 0  235811096.9  5.705882  168430090         0         0  168430090 ...
# 1  210145250.2  1.954839  168430090         0         0  168430090 ...
# 2  231723020.7  1.606936  168430090         0         0  168430090 ...
# 3  213925362.2  3.690058  168430090         0         0  168430090 ...
# 4  216854948.5  2.023392  168430090         0         0  168430090 ...
# 5  218507099.1  2.732558  168430090         0         0  168430090 ...
# 6  199870122.4  2.710983  168430090         0         0  168430090 ...
# 7  208066190.0  2.900585  168430090         0         0  168430090 ...
# 8  222714120.5  3.368421  168430090         0         0  168430090 ...
# 9  234432465.3  3.239766  168430090         0         0  168430090 ...
#
#    伺服负载电流(Amp)-A  伺服负载电流(Amp)-C  伺服负载电流(Amp)-X  伺服负载电流(Amp)-Y  伺服负载电流(Amp)-Z  \
# 0      72.411765              0      83.352941      22.000000      12.588235
# 1     115.058065              0      89.387097      -9.916129       1.445161
# 2     110.433526              0      88.283237      -2.404624       8.710983
# 3     114.035088              0      94.023392      -6.637427       0.883041
# 4     115.660819              0      90.941520      -6.912281       1.497076
# 5     112.819767              0      86.296512     -12.883721       4.773256
# 6     106.566474              0      94.329480      -1.797688      -0.439306
# 7     111.725146              0      89.771930      -7.099415      -1.111111
# 8     112.900585              0      85.947368      -2.040936       2.894737
# 9     113.298246              0      91.666667      -4.210526       8.842105
#
#      实际主轴转速       实际进给率   总件数  总件数_2  换刀
# 0  1.941176  580.647059 -1452  86562   0
# 1  0.503226  301.445161 -1451  86563   0
# 2  7.526012  235.994220 -1450  86564   0
# 3  3.859649  319.818714 -1449  86565   0
# 4  3.140351  381.350877 -1448  86566   0
# 5  0.744186  272.267442 -1447  86567   0
# 6  0.312139  320.421965 -1446  86568   0
# 7  0.304094  236.695906 -1445  86569   0
# 8  7.403509  307.865497 -1444  86570   0
# 9  3.432749  464.005848 -1443  86571   0
#
# [10 rows x 31 columns]

# %%
corrmat=hb_mean6.corr()
fig,ax=plt.subplots(figsize=(12,9))
sns.heatmap(corrmat,vmax=1.0,square=True)

# %%
import numpy as np
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False
k = 5 #number of variables for heatmap
cols = corrmat.nlargest(k, '主轴负载-S')['主轴负载-S'].index
cm = np.corrcoef(hb_mean6[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, 
yticklabels=cols.values, xticklabels=cols.values)
plt.show()
